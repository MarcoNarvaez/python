# %%
from PIL import Image
import os

downloads = '/home/marco/Downloads'

if __name__ == '__main__':
    for filename in os.listdir(downloads):
        name, extension = os.path.splitext(downloads + filename)
        
        if extension in ['.jpg', '.jpeg', '.png']:
            picture = Image.open(downloads + filename)
            picture.save(downloads + 'compressed_'+filename, optimaze=True, quality=60)
